# %% [markdown]
# # Lesson 3 Practice Pack
#
# This notebook is a companion file for **Lesson 3. Doing Math with Arrays**.
#
# It is designed as source material for the course builder. It contains:
# - quiz-style questions
# - CodeRunner-friendly tasks
# - open practice
# - one final mixed challenge
#
# **Main lesson topics**
# - elementwise arithmetic
# - scalar operations
# - comparisons
# - `sum`, `mean`, `min`, `max`
#
# **For the course builder**
# - items marked **[QUIZ]** can become multiple choice, short answer, or predict-the-output questions
# - items marked **[CODERUNNER]** are suitable for auto-checking
# - items marked **[OPEN]** work better as teacher-reviewed practice

# %% [markdown]
# ## Part 1. Quiz-style questions

# %% [markdown]
# ### Q1. [QUIZ]
# What is the result of `np.array([2, 4, 6]) + np.array([1, 3, 5])`?

# %% [markdown]
# ### Q2. [QUIZ]
# What is the result of `np.array([3, 6, 9]) * 2`?

# %% [markdown]
# ### Q3. [QUIZ]
# Which statement is true?
#
# A. Python lists and NumPy arrays use `+` in the same way.
#
# B. NumPy arrays usually use `+` for elementwise addition.

# %% [markdown]
# ### Q4. [QUIZ]
# Predict the output:
#
# ```python
# arr = np.array([8, 10, 12])
# print(arr - 3)
# ```

# %% [markdown]
# ### Q5. [QUIZ]
# Predict the boolean result:
#
# ```python
# arr = np.array([5, 9, 2, 11])
# arr > 6
# ```

# %% [markdown]
# ### Q6. [QUIZ]
# What does `arr.sum()` return?
#
# A. a new array
#
# B. one summary number

# %% [markdown]
# ### Q7. [QUIZ]
# Given `arr = np.array([4, 7, 1, 9])`, what is `arr.max()`?

# %% [markdown]
# ### Q8. [QUIZ]
# Given `arr = np.array([4, 7, 1, 9])`, what is `arr.min()`?

# %% [markdown]
# ### Q9. [QUIZ]
# Given `arr = np.array([2, 4, 6, 8])`, what is `arr.mean()`?

# %% [markdown]
# ### Q10. [QUIZ]
# True or false: comparisons like `arr >= 10` can return an array of `True` and `False` values.

# %% [markdown]
# ## Part 2. CodeRunner-friendly tasks

# %% [markdown]
# ### Task 1. [CODERUNNER] Add two arrays
# Create two arrays:
# - `a = [1, 2, 3]`
# - `b = [4, 5, 6]`
#
# Print:
# 1. `a`
# 2. `b`
# 3. `a + b`

# %%
# Write your code here

# %% [markdown]
# ### Task 2. [CODERUNNER] Multiply by a scalar
# Create an array called `levels` with values `[2, 5, 8, 11]`.
#
# Create a new array `double_levels` by multiplying every value by 2.
#
# Print `double_levels`.

# %%
# Write your code here

# %% [markdown]
# ### Task 3. [CODERUNNER] Build an expression
# Create an array `nums` with values `[3, 6, 9]`.
#
# Print the result of `nums * 2 + 1`.

# %%
# Write your code here

# %% [markdown]
# ### Task 4. [CODERUNNER] Boolean comparison
# Create an array `scores` with values `[12, 19, 7, 25]`.
#
# Print the result of:
# - `scores > 10`
# - `scores >= 20`

# %%
# Write your code here

# %% [markdown]
# ### Task 5. [CODERUNNER] Basic summaries
# Create an array `data` with values `[5, 10, 15, 20]`.
#
# Print:
# - `data.sum()`
# - `data.mean()`
# - `data.min()`
# - `data.max()`

# %%
# Write your code here

# %% [markdown]
# ### Task 6. [CODERUNNER] 2D array summary
# Create this array:
#
# ```python
# grid = np.array([
#     [2, 4],
#     [6, 8]
# ])
# ```
#
# Print:
# - the array
# - its sum
# - its mean

# %%
# Write your code here

# %% [markdown]
# ### Task 7. [CODERUNNER] Bonus points
# A game stores points in an array `[14, 9, 20, 11]`.
#
# Create an array `points`, then create `bonus_points` where every value is increased by 5.
#
# Print `bonus_points`.

# %%
# Write your code here

# %% [markdown]
# ### Task 8. [CODERUNNER] Energy filter
# Create an array `energy` with values `[3, 7, 10, 2, 9]`.
#
# Print:
# - `energy`
# - `energy > 5`
# - `energy * 3`

# %%
# Write your code here

# %% [markdown]
# ### Task 9. [CODERUNNER] Temperature summary
# Create an array `temps` with values `[17, 21, 19, 25, 16]`.
#
# Print:
# - the maximum temperature
# - the minimum temperature
# - the average temperature

# %%
# Write your code here

# %% [markdown]
# ## Part 3. Open practice

# %% [markdown]
# ### Task 10. [OPEN] Study planner
#
# A student tracked how many minutes they studied on five days:
#
# `[25, 40, 35, 50, 30]`
#
# Tasks:
# 1. create an array called `study_time`
# 2. create a new array where every value is increased by 10
# 3. print the total study time
# 4. print the average study time
# 5. print which days had more than 30 minutes of study

# %%
# Write your code here

# %% [markdown]
# ### Task 11. [OPEN] Team scores
#
# Two teams scored points in four rounds.
#
# - Team A: `[8, 12, 10, 14]`
# - Team B: `[7, 15, 9, 13]`
#
# Tasks:
# 1. create both arrays
# 2. print the combined score of the two teams for each round
# 3. print the difference `team_a - team_b`
# 4. print the total score of Team A
# 5. print whether Team B scored more than 10 in each round

# %%
# Write your code here

# %% [markdown]
# ## Part 4. Final mixed challenge

# %% [markdown]
# ### Task 12. [OPEN / COULD BECOME PROJECT]
#
# A small arcade records tickets won by players:
#
# ```python
# tickets = np.array([12, 18, 7, 25, 14])
# ```
#
# Complete the following:
# 1. print the array
# 2. create and print `double_tickets`
# 3. create and print `bonus_tickets` after adding 4 to every value
# 4. print the total number of tickets
# 5. print the average number of tickets
# 6. print the largest value
# 7. print which players won more than 15 tickets
#
# **Course builder note:** this can be split into:
# - one quiz question about prediction,
# - one CodeRunner task,
# - one short reflection question about reading boolean arrays.

# %%
# Write your code here

# %% [markdown]
# ## Notes for the course builder
#
# ### Best quiz candidates
# - output prediction for elementwise arithmetic
# - difference between list and array behavior
# - reading boolean arrays
# - identifying the meaning of `sum`, `mean`, `min`, `max`
#
# ### Best CodeRunner candidates
# - create arrays and apply arithmetic
# - scalar operations
# - print boolean comparisons
# - compute and print summary values
#
# ### Keep open-ended
# - word problems with scores, tickets, study minutes, temperatures
# - tasks where students must decide which operations to use
#
# ### Optional extension
# If the group is moving fast, add one short task where students compare two arrays and explain the result in words.
